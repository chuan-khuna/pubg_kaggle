# %%
import numpy as np

seed_ = 20200218

np.random.seed(seed_)

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

sns.set_style('whitegrid')
color_palette = sns.color_palette("muted")
sns.set_palette(color_palette)

from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)


def create_fig(figsize=(8,5), dpi=150):
    fig = plt.figure(figsize=figsize, dpi=dpi)
    return fig

# %% [markdown]
# ## Solo FPP Mode

# %%
df = pd.read_csv('./data/solofpp_train_clean.csv')
df.shape
# Out:
# (536723, 30)

# %%
df.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 1  311b84c6ff4390  eaba5fcb7fc1ae  292611730ca862        0       0
# 2  b7807186e3f679  3c08e461874749  2c30ddf481c52d        0       1
# 3  92022479b92ce7  2f2c33f548c4b9  07948d723b9c0f        0       3
# 4  47143f942503e0  e17a8867a393ec  bc2faecb77e5ec        0       0
#
#    damageDealt  headshotKills  heals  killPlace  killPoints  ...  \
# 0      100.000              0      0         45           0  ...
# 1        8.538              0      0         48        1000  ...
# 2      324.200              1      5          5         986  ...
# 3      254.300              0     12         13           0  ...
# 4      136.900              0      0         37           0  ...
#
#    swimDistance  teamKills  vehicleDestroys  walkDistance weaponsAcquired  \
# 0          0.00          0                0         49.75               2
# 1          0.00          0                0       1089.00               6
# 2         76.84          0                0       2050.00               6
# 3         15.29          0                0       1787.00               3
# 4          0.00          0                0        270.70               1
#
#    winPoints  headshotRate  totalDistance  itemUsed  winPlacePerc
# 0          0          0.00          49.75         0        0.1875
# 1       1500          0.00        3093.00         0        0.7368
# 2       1462          0.25        3354.84         6        0.8750
# 3          0          0.00        4169.29        15        0.8211
# 4          0          0.00         270.70         0        0.3474
#
# [5 rows x 30 columns]

# %% [markdown]
# ## drop column
#
# ดรอปส่วนที่ไม่เกี่ยวกับ Solo

# %%
df.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'rideDistance', 'roadKills', 'swimDistance',
#        'teamKills', 'vehicleDestroys', 'walkDistance', 'weaponsAcquired',
#        'winPoints', 'headshotRate', 'totalDistance', 'itemUsed',
#        'winPlacePerc'],
#       dtype='object')

# %%
df.drop(labels=['groupId', 'matchType'], axis=1, inplace=True)
df.head()
# Out:
#                Id         matchId  assists  boosts  damageDealt  \
# 0  315c96c26c9aac  6dc8ff871e21e6        0       0      100.000
# 1  311b84c6ff4390  292611730ca862        0       0        8.538
# 2  b7807186e3f679  2c30ddf481c52d        0       1      324.200
# 3  92022479b92ce7  07948d723b9c0f        0       3      254.300
# 4  47143f942503e0  bc2faecb77e5ec        0       0      136.900
#
#    headshotKills  heals  killPlace  killPoints  kills  ...  swimDistance  \
# 0              0      0         45           0      1  ...          0.00
# 1              0      0         48        1000      0  ...          0.00
# 2              1      5          5         986      4  ...         76.84
# 3              0     12         13           0      2  ...         15.29
# 4              0      0         37           0      1  ...          0.00
#
#    teamKills  vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 0          0                0         49.75                2          0
# 1          0                0       1089.00                6       1500
# 2          0                0       2050.00                6       1462
# 3          0                0       1787.00                3          0
# 4          0                0        270.70                1          0
#
#    headshotRate  totalDistance  itemUsed  winPlacePerc
# 0          0.00          49.75         0        0.1875
# 1          0.00        3093.00         0        0.7368
# 2          0.25        3354.84         6        0.8750
# 3          0.00        4169.29        15        0.8211
# 4          0.00         270.70         0        0.3474
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Split train & test

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(labels=['Id', 'winPlacePerc', 'numGroups', 'matchId'], axis=1), df['winPlacePerc'], test_size=0.2, random_state=seed_)

X_train.head()
# Out:
#         assists  boosts  damageDealt  headshotKills  heals  killPlace  \
# 475572        0       2        100.0              0      3         27
# 232000        0       0        130.1              0      0         43
# 137292        0       0          0.0              0      0         86
# 67745         0       4          0.0              0      1         61
# 369880        0       0          0.0              0      0         64
#
#         killPoints  kills  killStreaks  longestKill  ...  roadKills  \
# 475572           0      1            1       23.950  ...          0
# 232000        1342      1            1        6.372  ...          0
# 137292         991      0            0        0.000  ...          0
# 67745            0      0            0        0.000  ...          0
# 369880           0      0            0        0.000  ...          0
#
#         swimDistance  teamKills  vehicleDestroys  walkDistance  \
# 475572        219.90          0                0       811.900
# 232000          0.00          0                0       151.500
# 137292          0.00          0                0         2.765
# 67745           7.15          0                0      2276.000
# 369880          0.00          0                0       544.600
#
#         weaponsAcquired  winPoints  headshotRate  totalDistance  itemUsed
# 475572                7          0           0.0      1031.8000         5
# 232000                2       1472           0.0       151.5000         0
# 137292                0       1477           0.0         2.7650         0
# 67745                 3          0           0.0      2283.1618         5
# 369880                4          0           0.0       861.1000         0
#
# [5 rows x 24 columns]

# %%
X_train.shape, X_test.shape
# Out:
# ((429378, 24), (107345, 24))

# %% [markdown]
# # ...
# # Create Model
# # ...

# %%
model = Sequential()


model.add(Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(1, activation='sigmoid'))


opt = SGD(lr=0.01)
model.compile(opt, loss='mae', metrics=['mae'])
early_stop = EarlyStopping(monitor='val_mean_absolute_error', patience=5)


model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               3200
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16)                64
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 15,041
# Trainable params: 14,561
# Non-trainable params: 480
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=20000, callbacks=[early_stop], verbose=1)
# Out:
# Train on 343502 samples, validate on 85876 samples
# Epoch 1/100
# 343502/343502 [==============================] - 4s 10us/step - loss: 0.1966 - mae: 0.1966 - val_loss: 0.3086 - val_mae: 0.3086
# Epoch 2/100
# c:\users\chuan\appdata\local\programs\python\python38\lib\site-packages\keras\callbacks\callbacks.py:843: RuntimeWarning: Early stopping conditioned on metric `val_mean_absolute_error` which is not available. Available metrics are: val_loss,val_mae,loss,mae
#   warnings.warn(
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.1063 - mae: 0.1063 - val_loss: 0.2362 - val_mae: 0.2362
# Epoch 3/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0917 - mae: 0.0917 - val_loss: 0.2046 - val_mae: 0.2046
# Epoch 4/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0870 - mae: 0.0870 - val_loss: 0.1860 - val_mae: 0.1860
# Epoch 5/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0847 - mae: 0.0847 - val_loss: 0.1695 - val_mae: 0.1695
# Epoch 6/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0827 - mae: 0.0827 - val_loss: 0.1535 - val_mae: 0.1535
# Epoch 7/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0815 - mae: 0.0815 - val_loss: 0.1384 - val_mae: 0.1384
# Epoch 8/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0806 - mae: 0.0806 - val_loss: 0.1230 - val_mae: 0.1230
# Epoch 9/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.1110 - val_mae: 0.1110
# Epoch 10/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0789 - mae: 0.0789 - val_loss: 0.1035 - val_mae: 0.1035
# Epoch 11/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0785 - mae: 0.0785 - val_loss: 0.1000 - val_mae: 0.1000
# Epoch 12/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0784 - mae: 0.0784 - val_loss: 0.0925 - val_mae: 0.0925
# Epoch 13/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0776 - mae: 0.0776 - val_loss: 0.0888 - val_mae: 0.0888
# Epoch 14/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0770 - mae: 0.0770 - val_loss: 0.0871 - val_mae: 0.0871
# Epoch 15/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0765 - mae: 0.0765 - val_loss: 0.0841 - val_mae: 0.0841
# Epoch 16/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0760 - mae: 0.0760 - val_loss: 0.0822 - val_mae: 0.0822
# Epoch 17/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0757 - mae: 0.0757 - val_loss: 0.0801 - val_mae: 0.0801
# Epoch 18/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0752 - mae: 0.0752 - val_loss: 0.0789 - val_mae: 0.0789
# Epoch 19/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0749 - mae: 0.0749 - val_loss: 0.0779 - val_mae: 0.0779
# Epoch 20/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0746 - mae: 0.0746 - val_loss: 0.0773 - val_mae: 0.0773
# Epoch 21/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0743 - mae: 0.0743 - val_loss: 0.0763 - val_mae: 0.0763
# Epoch 22/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0740 - mae: 0.0740 - val_loss: 0.0759 - val_mae: 0.0759
# Epoch 23/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0738 - mae: 0.0738 - val_loss: 0.0752 - val_mae: 0.0752
# Epoch 24/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0735 - mae: 0.0735 - val_loss: 0.0752 - val_mae: 0.0752
# Epoch 25/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0734 - mae: 0.0734 - val_loss: 0.0745 - val_mae: 0.0745
# Epoch 26/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0731 - mae: 0.0731 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 27/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0739 - mae: 0.0739 - val_loss: 0.0776 - val_mae: 0.0776
# Epoch 28/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0748 - val_mae: 0.0748
# Epoch 29/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0729 - mae: 0.0729 - val_loss: 0.0738 - val_mae: 0.0738
# Epoch 30/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0727 - mae: 0.0727 - val_loss: 0.0735 - val_mae: 0.0735
# Epoch 31/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0726 - mae: 0.0726 - val_loss: 0.0731 - val_mae: 0.0731
# Epoch 32/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0724 - mae: 0.0724 - val_loss: 0.0741 - val_mae: 0.0741
# Epoch 33/100
# 343502/343502 [==============================] - 3s 10us/step - loss: 0.0723 - mae: 0.0723 - val_loss: 0.0729 - val_mae: 0.0729
# Epoch 34/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0721 - mae: 0.0721 - val_loss: 0.0725 - val_mae: 0.0725
# Epoch 35/100
# 343502/343502 [==============================] - 4s 11us/step - loss: 0.0721 - mae: 0.0721 - val_loss: 0.0724 - val_mae: 0.0724
# Epoch 36/100
# 343502/343502 [==============================] - 3s 10us/step - loss: 0.0719 - mae: 0.0719 - val_loss: 0.0719 - val_mae: 0.0719
# Epoch 37/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0718 - mae: 0.0718 - val_loss: 0.0721 - val_mae: 0.0721
# Epoch 38/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0717 - mae: 0.0717 - val_loss: 0.0718 - val_mae: 0.0718
# Epoch 39/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0716 - mae: 0.0716 - val_loss: 0.0715 - val_mae: 0.0715
# Epoch 40/100
# 343502/343502 [==============================] - 3s 10us/step - loss: 0.0715 - mae: 0.0715 - val_loss: 0.0715 - val_mae: 0.0715
# Epoch 41/100
# 343502/343502 [==============================] - 3s 10us/step - loss: 0.0714 - mae: 0.0714 - val_loss: 0.0721 - val_mae: 0.0721
# Epoch 42/100
# 343502/343502 [==============================] - 4s 11us/step - loss: 0.0713 - mae: 0.0713 - val_loss: 0.0714 - val_mae: 0.0714
# Epoch 43/100
# 343502/343502 [==============================] - 3s 10us/step - loss: 0.0713 - mae: 0.0713 - val_loss: 0.0712 - val_mae: 0.0712
# Epoch 44/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0711 - mae: 0.0711 - val_loss: 0.0714 - val_mae: 0.0714
# Epoch 45/100
# 343502/343502 [==============================] - 3s 10us/step - loss: 0.0711 - mae: 0.0711 - val_loss: 0.0710 - val_mae: 0.0710
# Epoch 46/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0710 - mae: 0.0710 - val_loss: 0.0718 - val_mae: 0.0718
# Epoch 47/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0709 - mae: 0.0709 - val_loss: 0.0708 - val_mae: 0.0708
# Epoch 48/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0708 - mae: 0.0708 - val_loss: 0.0710 - val_mae: 0.0710
# Epoch 49/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0708 - mae: 0.0708 - val_loss: 0.0707 - val_mae: 0.0707
# Epoch 50/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0706 - mae: 0.0706 - val_loss: 0.0706 - val_mae: 0.0706
# Epoch 51/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0705 - mae: 0.0705 - val_loss: 0.0706 - val_mae: 0.0706
# Epoch 52/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0705 - mae: 0.0705 - val_loss: 0.0706 - val_mae: 0.0706
# Epoch 53/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0704 - mae: 0.0704 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 54/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0704 - mae: 0.0704 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 55/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0703 - mae: 0.0703 - val_loss: 0.0703 - val_mae: 0.0703
# Epoch 56/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0703 - mae: 0.0703 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 57/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0702 - mae: 0.0702 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 58/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0701 - mae: 0.0701 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 59/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0701 - mae: 0.0701 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 60/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0701 - mae: 0.0701 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 61/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0700 - mae: 0.0700 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 62/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0700 - mae: 0.0700 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 63/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0699 - mae: 0.0699 - val_loss: 0.0700 - val_mae: 0.0700
# Epoch 64/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0699 - mae: 0.0699 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 65/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0698 - mae: 0.0698 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 66/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0697 - mae: 0.0697 - val_loss: 0.0698 - val_mae: 0.0698
# Epoch 67/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0697 - mae: 0.0697 - val_loss: 0.0697 - val_mae: 0.0697
# Epoch 68/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0696 - mae: 0.0696 - val_loss: 0.0700 - val_mae: 0.0700
# Epoch 69/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0696 - mae: 0.0696 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 70/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0696 - mae: 0.0696 - val_loss: 0.0696 - val_mae: 0.0696
# Epoch 71/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0695 - mae: 0.0695 - val_loss: 0.0698 - val_mae: 0.0698
# Epoch 72/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0695 - mae: 0.0695 - val_loss: 0.0695 - val_mae: 0.0695
# Epoch 73/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0695 - mae: 0.0695 - val_loss: 0.0696 - val_mae: 0.0696
# Epoch 74/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0694 - mae: 0.0694 - val_loss: 0.0694 - val_mae: 0.0694
# Epoch 75/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0694 - mae: 0.0694 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 76/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0693 - mae: 0.0693 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 77/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0692 - mae: 0.0692 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 78/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0692 - mae: 0.0692 - val_loss: 0.0692 - val_mae: 0.0692
# Epoch 79/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0692 - mae: 0.0692 - val_loss: 0.0692 - val_mae: 0.0692
# Epoch 80/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0691 - mae: 0.0691 - val_loss: 0.0696 - val_mae: 0.0696
# Epoch 81/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0691 - mae: 0.0691 - val_loss: 0.0690 - val_mae: 0.0690
# Epoch 82/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0690 - mae: 0.0690 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 83/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0690 - mae: 0.0690 - val_loss: 0.0691 - val_mae: 0.0691
# Epoch 84/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0690 - mae: 0.0690 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 85/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0690 - mae: 0.0690 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 86/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0689 - mae: 0.0689 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 87/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0688 - mae: 0.0688 - val_loss: 0.0691 - val_mae: 0.0691
# Epoch 88/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0689 - mae: 0.0689 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 89/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0688 - mae: 0.0688 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 90/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0688 - mae: 0.0688 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 91/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0687 - mae: 0.0687 - val_loss: 0.0688 - val_mae: 0.0688
# Epoch 92/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0687 - mae: 0.0687 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 93/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0687 - mae: 0.0687 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 94/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0687 - mae: 0.0687 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 95/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 96/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 97/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 98/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 99/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0685 - mae: 0.0685 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 100/100
# 343502/343502 [==============================] - 3s 9us/step - loss: 0.0685 - mae: 0.0685 - val_loss: 0.0684 - val_mae: 0.0684

# %%
epoch = np.arange(1, len(history.history['mae'])+1)

create_fig()
sns.lineplot(epoch, history.history['mae'], label='mae')
sns.lineplot(epoch, history.history['val_mae'], label='val_mae')

# %%
model.evaluate(X_test, y_test)
# Out:
# 107345/107345 [==============================] - 2s 17us/step
# [0.06830403095795698, 0.06830406934022903]

# %%
predict = model.predict(X_test).flatten()

# %%
create_fig()
plt.plot(predict, y_test,  'o', alpha=0.1, markersize=1)
sns.lineplot([0, 1], [0, 1], color='k')
plt.xlabel('predict winPlacePerc')
plt.ylabel('actual winPlacePerc')
# Out:
# Text(0, 0.5, 'actual winPlacePerc')
